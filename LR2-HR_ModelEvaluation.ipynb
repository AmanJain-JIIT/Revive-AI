# %%
import import_ipynb
import Utilities
# Out:
# importing Jupyter notebook from Utilities.ipynb
# importing Jupyter notebook from srcnnModel.ipynb
# importing Jupyter notebook from vdsrcnnModel.ipynb

# %%
modelType = "srcnn"
modelPath = "A:\WORK\Projects\Machine Learning\Revive-AI\Models\SRCNN_Models\modelM1(512x512).h5"
size=512

# %%
modelReport = Utilities.evaluate(1, modelType, modelPath, size)
# Out:
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 modelReport = Utilities.evaluate(1, modelType, modelPath, size)
#
# File <string>:4, in evaluate(batches, modelType, modelPath, size)
#
# File <string>:17, in evaluateModel(modelType, modelPath, batch, size)
#
# File c:\Users\amanj\miniconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
Utilities.analyzeModelReport(modelReport)
# Out:
# Results on batch  1
#                     Low Res Image     Reconstructed Image
# Mininum PSNR        22.64             23.60
# Maximum PSNR        38.51             40.50
# Average PSNR        30.15             30.83
#
#
# Results on batch  2
#                     Low Res Image     Reconstructed Image
# Mininum PSNR        22.78             23.44
# Maximum PSNR        38.89             39.76
# Average PSNR        30.16             30.91
#
#
# Results on batch  3
#                     Low Res Image     Reconstructed Image
# Mininum PSNR        23.32             23.86
# Maximum PSNR        39.40             39.98
# Average PSNR        30.96             31.61
#
#
# Results on batch  4
#                     Low Res Image     Reconstructed Image
# Mininum PSNR        24.26             24.80
# Maximum PSNR        38.73             40.60
# Average PSNR        30.64             31.36
#
#
# Results on batch  5
#                     Low Res Image     Reconstructed Image
# ...
